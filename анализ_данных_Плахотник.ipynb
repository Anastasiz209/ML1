# %% [markdown]
# <a href="https://colab.research.google.com/github/Anastasiz209/ML1/blob/main/%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85_%D0%9F%D0%BB%D0%B0%D1%85%D0%BE%D1%82%D0%BD%D0%B8%D0%BA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Привязка гугл диска
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Анализ данных с гугл диска
df = pd.read_csv('/content/drive/MyDrive/ParsedLogsCian.csv')
df.head()
# Out:
#                               author        author_type  \
# 0                       ID 115709096          homeowner
# 1  Самолёт плюс Подмосковье Серпухов  real_estate_agent
# 2                         ID 3246838            realtor
# 3                        ID 64398571            unknown
# 4                          ЛИДЕРМЭЙН  real_estate_agent
#
#                                               url  location deal_type  \
# 0  https://serpukhov.cian.ru/sale/flat/301136001/  Серпухов      sale
# 1  https://serpukhov.cian.ru/sale/flat/305145433/  Серпухов      sale
# 2  https://serpukhov.cian.ru/sale/flat/308145954/  Серпухов      sale
# 3  https://serpukhov.cian.ru/sale/flat/309086009/  Серпухов      sale
# 4  https://serpukhov.cian.ru/sale/flat/308401669/  Серпухов      sale
#
#   accommodation_type floor floors_count rooms_count total_meters  ...  \
# 0               flat     6            6           1         20.7  ...
# 1               flat     1            9           1         33.0  ...
# 2               flat     4            4           1         14.0  ...
# 3               flat     5            5           1         17.5  ...
# 4               flat     4            7           1         25.9  ...
#
#   finish_type living_meters kitchen_meters        phone ceiling_height  \
# 0          -1         18 м²           1 м²  79175096253            3 м
# 1          -1         18 м²           6 м²  79645530086          2,7 м
# 2          -1            -1             -1  79807126116             -1
# 3          -1            -1             -1  79645652380             -1
# 4          -1         20 м²           5 м²  79099408093          3,5 м
#
#                   district                street house_number underground  \
# 0                 Серпухов               Крюкова            4         NaN
# 1                      NaN            Ворошилова          144      Аннино
# 2  Красный Текстильщик мкр   Красный Текстильщик            2         NaN
# 3                 Серпухов           Российская            40         NaN
# 4                 Серпухов               Химиков            8         NaN
#
#   residential_complex
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 27 columns]

# %%
print(f'Data has {df.shape[0]} rows , {df.shape[1]} columns.') # Вывод кол-во строк и столбцов
# Out:
# Data has 8393 rows , 27 columns.

# %%
sns.heatmap(df.isnull(),cmap='Oranges') # Проверка пропусков в данных
# Out:
# <Axes: >

# %%
df.drop(['author'], axis=1,inplace=True)
print(f'Data after dropping col "ID" has  {df.shape[1]} columns.')
# Out:
# Data after dropping col "ID" has  25 columns.

# %%
df.info() #посмотрим информацию о df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8392 entries, 0 to 8392
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   author                8392 non-null   int64
#  1   author_type           8392 non-null   int64
#  2   location              8392 non-null   int64
#  3   accommodation_type    8392 non-null   int64
#  4   floor                 7904 non-null   float64
#  5   floors_count          7904 non-null   float64
#  6   rooms_count           7904 non-null   float64
#  7   total_meters          7904 non-null   float64
#  8   price                 7891 non-null   float64
#  9   year_of_construction  8392 non-null   int64
#  10  object_type           8392 non-null   int64
#  11  have_loggia           8392 non-null   int64
#  12  parking_type          8392 non-null   int64
#  13  house_material_type   8392 non-null   int64
#  14  heating_type          8392 non-null   int64
#  15  finish_type           8392 non-null   int64
#  16  living_meters         8392 non-null   int64
#  17  kitchen_meters        8392 non-null   int64
#  18  phone                 8392 non-null   int64
#  19  ceiling_height        8392 non-null   int64
#  20  district              8392 non-null   int64
#  21  street                8392 non-null   int64
#  22  house_number          8392 non-null   int64
#  23  underground           8392 non-null   int64
#  24  residential_complex   8392 non-null   int64
#  25  price_for_metr        7891 non-null   float64
# dtypes: float64(6), int64(20)
# memory usage: 2.0 MB

# %%
df.isnull().sum() #кол-во пропусков
# Out:
# author                    0
# author_type               0
# location                  0
# accommodation_type        0
# floor                   488
# floors_count            488
# rooms_count             488
# total_meters            488
# price                   501
# year_of_construction      0
# object_type               0
# have_loggia               0
# parking_type              0
# house_material_type       0
# heating_type              0
# finish_type               0
# living_meters             0
# kitchen_meters            0
# phone                     0
# ceiling_height            0
# district                  0
# street                    0
# house_number              0
# underground               0
# residential_complex       0
# price_for_metr          501
# dtype: int64

# %% [markdown]
# # *Дроп NAN*

# %%
print(df["district"].isnull().sum(),"-nulls in district")
print(df["underground"].isnull().sum(),"-nulls in underground")
print(df["residential_complex"].isnull().sum(),"-nulls in residential_complex")
print(df["street"].isnull().sum(),"-nulls in street")
# Out:
# 0 -nulls in district
# 0 -nulls in underground
# 0 -nulls in residential_complex
# 0 -nulls in street

# %%
sns.heatmap(df.isnull(), cmap = "OrRd") #проверяем кол-во пропусков
# Out:
# <Axes: >

# %% [markdown]
# # *Приведение* *типов*

# %%
df['floor'] = pd.to_numeric(df['floor'], errors='coerce')
df['floors_count'] = pd.to_numeric(df['floors_count'], errors='coerce')
df['total_meters'] = pd.to_numeric(df['total_meters'], errors='coerce')
df['price'] = pd.to_numeric(df['price'], errors='coerce')
df['rooms_count'] = pd.to_numeric(df['rooms_count'], errors='coerce')

# %%
df['price_for_metr'] = round((df['price'] / df['total_meters']), 3)
df["price_for_metr"] # Перевод данных в численные (которые должны таковыми являться)
# Out:
# 0       113526.570
# 1       125757.576
# 2       121428.571
# 3       142857.143
# 4       115830.116
#            ...
# 8388    163558.106
# 8389    178940.000
# 8390    162222.222
# 8391    188235.294
# 8392    222087.986
# Name: price_for_metr, Length: 8393, dtype: float64

# %% [markdown]
# # *Поиск выбросов*

# %%
print(df.loc[df['price_for_metr'].idxmax()])
print(df.loc[df['floors_count'].idxmax()])
print(df.loc[df['rooms_count'].idxmax()])
# Out:
# author                                                    VESPER
# author_type                                            developer
# url                     https://www.cian.ru/sale/flat/308564823/
# location                                                  Москва
# deal_type                                                   sale
# accommodation_type                                          flat
# floor                                                        5.0
# floors_count                                                 5.0
# rooms_count                                                  5.0
# total_meters                                               590.3
# price                                               2361200000.0
# year_of_construction                                        2027
# object_type                                          Новостройка
# have_loggia                                                   -1
# parking_type                                                  -1
# house_material_type                                           -1
# heating_type                                                  -1
# finish_type                                   Чистовая с мебелью
# living_meters                                                 -1
# kitchen_meters                                                -1
# phone                                                74951346294
# ceiling_height                                               3 м
# district                                             Пресненский
# street                                      Трехпрудный переулок
# house_number                                                 9С1
# underground                                           Маяковская
# residential_complex                         Клубный дом Левенсон
# price_for_metr                                         4000000.0
# Name: 5851, dtype: object
# author                                     Whitewill Москва-Сити
# author_type                                    real_estate_agent
# url                     https://www.cian.ru/sale/flat/304787065/
# location                                              Котельники
# deal_type                                                   sale
# accommodation_type                                          flat
# floor                                                       79.0
# floors_count                                                97.0
# rooms_count                                                  1.0
# total_meters                                                73.0
# price                                                 72900000.0
# year_of_construction                                          -1
# object_type                               Вторичка / Апартаменты
# have_loggia                                                   -1
# parking_type                                                  -1
# house_material_type                                           -1
# heating_type                                                  -1
# finish_type                                                   -1
# living_meters                                              50 м²
# kitchen_meters                                             18 м²
# phone                                                79850016320
# ceiling_height                                                -1
# district                                             Пресненский
# street                                    набережная Пресненская
# house_number                                                  12
# underground                                        Деловой центр
# residential_complex                              Башня Федерация
# price_for_metr                                        998630.137
# Name: 3684, dtype: object
# author                                           ANT Development
# author_type                                            developer
# url                     https://www.cian.ru/sale/flat/303519398/
# location                                                  Москва
# deal_type                                                   sale
# accommodation_type                                          flat
# floor                                                       11.0
# floors_count                                                13.0
# rooms_count                                                  5.0
# total_meters                                               265.6
# price                                                405328840.0
# year_of_construction                                        2024
# object_type                                          Новостройка
# have_loggia                                                   -1
# parking_type                                                  -1
# house_material_type                                   Монолитный
# heating_type                                                  -1
# finish_type                                             Чистовая
# living_meters                                                 -1
# kitchen_meters                                                -1
# phone                                                74951346248
# ceiling_height                                               3 м
# district                                            Дорогомилово
# street                                                       NaN
# house_number                                                 3к1
# underground                                          Парк Победы
# residential_complex                   Виктори Парк Резиденсез ЖК
# price_for_metr                                         1526087.5
# Name: 1157, dtype: object

# %%
df.drop(([df['rooms_count'].idxmax()]), axis = 0, inplace=True)
print(df.loc[df['rooms_count'].idxmax()])
# Out:
# author                                               ID 18174647
# author_type                                              realtor
# url                     https://www.cian.ru/sale/flat/301450189/
# location                                                  Москва
# deal_type                                                   sale
# accommodation_type                                          flat
# floor                                                       26.0
# floors_count                                                31.0
# rooms_count                                                  5.0
# total_meters                                               246.7
# price                                                288063785.0
# year_of_construction                                        2008
# object_type                                             Вторичка
# have_loggia                                            3 балкона
# parking_type                                           Подземная
# house_material_type                                           -1
# heating_type                                                  -1
# finish_type                                                   -1
# living_meters                                           140,9 м²
# kitchen_meters                                             28 м²
# phone                                                79166462390
# ceiling_height                                             3,1 м
# district                                     Очаково-Матвеевское
# street                                                Нежинская
# house_number                                                 1к1
# underground                                            Давыдково
# residential_complex                          Кутузовская Ривьера
# price_for_metr                                       1167668.362
# Name: 1158, dtype: object

# %%
print(f"было {df.shape[0]} строк")
df.drop(df[df['rooms_count'] > 10].index, inplace=True)
print(f"стало {df.shape[0]} строк")
print(df.loc[df['rooms_count'].idxmax()])
# Out:
# было 8392 строк
# стало 8392 строк
# author                                               ID 18174647
# author_type                                              realtor
# url                     https://www.cian.ru/sale/flat/301450189/
# location                                                  Москва
# deal_type                                                   sale
# accommodation_type                                          flat
# floor                                                       26.0
# floors_count                                                31.0
# rooms_count                                                  5.0
# total_meters                                               246.7
# price                                                288063785.0
# year_of_construction                                        2008
# object_type                                             Вторичка
# have_loggia                                            3 балкона
# parking_type                                           Подземная
# house_material_type                                           -1
# heating_type                                                  -1
# finish_type                                                   -1
# living_meters                                           140,9 м²
# kitchen_meters                                             28 м²
# phone                                                79166462390
# ceiling_height                                             3,1 м
# district                                     Очаково-Матвеевское
# street                                                Нежинская
# house_number                                                 1к1
# underground                                            Давыдково
# residential_complex                          Кутузовская Ривьера
# price_for_metr                                       1167668.362
# Name: 1158, dtype: object

# %% [markdown]
# # *анализ* *данных*

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['price_for_metr'], bins=30, color='Orange', edgecolor='red')
plt.title('Распределение цены квадратного метра')
plt.xlabel('Цена за квадратный метр')
plt.ylabel('Частота')
plt.show()

# %%
# Пример для признака 'total_sqm' (общее количество метров)
plt.figure(figsize=(10, 6))
plt.hist(df['total_meters'], bins=30, color='lavender', edgecolor='plum')
plt.title('Распределение общего количества метров')
plt.xlabel('Общее количество метров')
plt.ylabel('Частота')
plt.show()

# %%
print(df.loc[df['total_meters'].idxmax()])
# Out:
# author                                                    VESPER
# author_type                                            developer
# url                     https://www.cian.ru/sale/flat/308564823/
# location                                                  Москва
# deal_type                                                   sale
# accommodation_type                                          flat
# floor                                                        5.0
# floors_count                                                 5.0
# rooms_count                                                  5.0
# total_meters                                               590.3
# price                                               2361200000.0
# year_of_construction                                        2027
# object_type                                          Новостройка
# have_loggia                                                   -1
# parking_type                                                  -1
# house_material_type                                           -1
# heating_type                                                  -1
# finish_type                                   Чистовая с мебелью
# living_meters                                                 -1
# kitchen_meters                                                -1
# phone                                                74951346294
# ceiling_height                                               3 м
# district                                             Пресненский
# street                                      Трехпрудный переулок
# house_number                                                 9С1
# underground                                           Маяковская
# residential_complex                         Клубный дом Левенсон
# price_for_metr                                         4000000.0
# Name: 5851, dtype: object

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['floors_count'], bins=30, color='azure', edgecolor='indigo')
plt.title('Распределение общего количества этажей')
plt.xlabel('Общее количество этажей')
plt.ylabel('Частота')
plt.show()

# %%
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Создаем матрицу корреляции
corr_matrix = df[numeric_cols].corr()

# Визуализация матрицы корреляции
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='BuPu', fmt='.2f')
plt.title('Матрица корреляции')
plt.show()

# %% [markdown]
# сильно влияют цена и площадь квартиры, немного меньше влияет количество комнат. На цену влияют площадь и кол-во комнат. этаж коррелируют количество этажей. Площадь коррелирует с колвом комнат и ценой.

# %% [markdown]
# # *Преобразование категориальных данных в числа*

# %%
df.drop(['url'], axis=1,inplace=True) #не влияет
df.drop(['deal_type'], axis=1,inplace=True) #везде повторяются

# %%
from sklearn.preprocessing import OrdinalEncoder

categorical_columns = df.select_dtypes(include=['object']).columns.tolist()

ordinal_encoder = OrdinalEncoder()
encoded_data = ordinal_encoder.fit_transform(df[categorical_columns])
df[categorical_columns] = encoded_data.astype(int)


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8392 entries, 0 to 8392
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   author                8392 non-null   int64
#  1   author_type           8392 non-null   int64
#  2   location              8392 non-null   int64
#  3   accommodation_type    8392 non-null   int64
#  4   floor                 7904 non-null   float64
#  5   floors_count          7904 non-null   float64
#  6   rooms_count           7904 non-null   float64
#  7   total_meters          7904 non-null   float64
#  8   price                 7891 non-null   float64
#  9   year_of_construction  8392 non-null   int64
#  10  object_type           8392 non-null   int64
#  11  have_loggia           8392 non-null   int64
#  12  parking_type          8392 non-null   int64
#  13  house_material_type   8392 non-null   int64
#  14  heating_type          8392 non-null   int64
#  15  finish_type           8392 non-null   int64
#  16  living_meters         8392 non-null   int64
#  17  kitchen_meters        8392 non-null   int64
#  18  phone                 8392 non-null   int64
#  19  ceiling_height        8392 non-null   int64
#  20  district              8392 non-null   int64
#  21  street                8392 non-null   int64
#  22  house_number          8392 non-null   int64
#  23  underground           8392 non-null   int64
#  24  residential_complex   8392 non-null   int64
#  25  price_for_metr        7891 non-null   float64
# dtypes: float64(6), int64(20)
# memory usage: 2.0 MB
# <ipython-input-35-e9815df47316>:7: RuntimeWarning: invalid value encountered in cast
#   df[categorical_columns] = encoded_data.astype(int)

# %%
numeric_cols = ["author_type",'location','district',"street","underground","residential_complex","price_for_metr"]

# Создаем матрицу корреляции
corr_matrix = df[numeric_cols].corr()

# Визуализация матрицы корреляции
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='Spectral', fmt='.2f')
plt.title('Матрица корреляции')
plt.show()

# %% [markdown]
# на целевую переменную расположение коррелирует очень слабо
